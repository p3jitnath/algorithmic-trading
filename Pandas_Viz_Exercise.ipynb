# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
import numpy as np
import pandas as pd

# %%
BASE_PATH = '../04-Visualization-Matplotlib-Pandas/04-02-Pandas Visualization/'

# %%
df3 = pd.read_csv(BASE_PATH + 'df3')

# %%
df3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %%
df3.plot.scatter(x='a', y='b', figsize=(12, 4), s=50, c='r')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df3['a'].hist()
# Out:
# <AxesSubplot:>

# %%
df3['a'].hist(bins=20, alpha=0.5)
# Out:
# <AxesSubplot:>

# %%
df3[['a', 'b']].boxplot()
# Out:
# <AxesSubplot:>

# %%
df3['d'].plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df3['d'].plot.density(lw='3', ls='--')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df3.iloc[0:30].plot.area(alpha=0.4)
# Out:
# <AxesSubplot:>

# %%
df3.iloc[0:30].plot.area(alpha=0.4)
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
