# %%
import pyfolio as pf
import matplotlib.pyplot as plt
import empyrical

# %%
bt = get_backtest('5f2ef8f683fe3a46f7872cf8')
# Out:
# 100% Time:  0:00:00|##########################################################|

# %%
bt_returns = bt.daily_performance['returns']
bt_positions = bt.pyfolio_positions
bt_transactions = bt.pyfolio_transactions

# %%
bm = get_backtest('5f2efa9a21785a46dc9b2e9d')
bm_returns = bm.daily_performance['returns']
bm_positions = bm.pyfolio_positions
bm_transactions = bm.pyfolio_transactions
# Out:
# 100% Time:  0:00:00|##########################################################|

# %%
empyrical.sharpe_ratio(bt_returns)
# Out:
# 1.3175719236066508

# %%
empyrical.sharpe_ratio(bm_returns)
# Out:
# 0.4684586666069403

# %%
empyrical.beta(bt_returns, bm_returns)
# Out:
# 0.06464573965464868

# %%
plt.subplot(2, 1, 1)
pf.plotting.plot_rolling_returns(bt_returns, bm_returns)

plt.subplot(2, 1, 2)
pf.plotting.plot_returns(bt_returns)
plt.tight_layout()

# %%
fig = plt.figure()
plt.subplot(1, 3, 1)
pf.plot_annual_returns(bt_returns)
plt.subplot(1, 3, 2)
pf.plot_monthly_returns_dist(bt_returns)
plt.subplot(1, 3, 3)
pf.plot_monthly_returns_heatmap(bt_returns)
plt.tight_layout()

# %%
pf.plot_return_quantiles(bt_returns)

# %%
pf.plot_rolling_beta(bt_returns, bm_returns)

# %%
pf.plot_rolling_sharpe(bt_returns)

# %%
pf.plot_drawdown_periods(bt_returns)

# %%
pf.plot_drawdown_underwater(bt_returns)

# %%
pf.plot_gross_leverage(bt_returns, bt_positions)

# %%
pf.create_round_trip_tear_sheet(bt_returns, bt_positions, bt_transactions)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Summary stats</th>
#       <th>All trades</th>
#       <th>Short trades</th>
#       <th>Long trades</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Total number of round_trips</th>
#       <td>518.00</td>
#       <td>251.00</td>
#       <td>267.00</td>
#     </tr>
#     <tr>
#       <th>Percent profitable</th>
#       <td>0.70</td>
#       <td>0.42</td>
#       <td>0.97</td>
#     </tr>
#     <tr>
#       <th>Winning round_trips</th>
#       <td>365.00</td>
#       <td>106.00</td>
#       <td>259.00</td>
#     </tr>
#     <tr>
#       <th>Losing round_trips</th>
#       <td>153.00</td>
#       <td>145.00</td>
#       <td>8.00</td>
#     </tr>
#     <tr>
#       <th>Even round_trips</th>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.00</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>PnL stats</th>
#       <th>All trades</th>
#       <th>Short trades</th>
#       <th>Long trades</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Total profit</th>
#       <td>$5339148.14</td>
#       <td>$-596039.31</td>
#       <td>$5935187.45</td>
#     </tr>
#     <tr>
#       <th>Gross profit</th>
#       <td>$7248614.13</td>
#       <td>$1292524.03</td>
#       <td>$5956090.10</td>
#     </tr>
#     <tr>
#       <th>Gross loss</th>
#       <td>$-1909465.99</td>
#       <td>$-1888563.34</td>
#       <td>$-20902.65</td>
#     </tr>
#     <tr>
#       <th>Profit factor</th>
#       <td>$3.80</td>
#       <td>$0.68</td>
#       <td>$284.94</td>
#     </tr>
#     <tr>
#       <th>Avg. trade net profit</th>
#       <td>$10307.24</td>
#       <td>$-2374.66</td>
#       <td>$22229.17</td>
#     </tr>
#     <tr>
#       <th>Avg. winning trade</th>
#       <td>$19859.22</td>
#       <td>$12193.62</td>
#       <td>$22996.49</td>
#     </tr>
#     <tr>
#       <th>Avg. losing trade</th>
#       <td>$-12480.17</td>
#       <td>$-13024.57</td>
#       <td>$-2612.83</td>
#     </tr>
#     <tr>
#       <th>Ratio Avg. Win:Avg. Loss</th>
#       <td>$1.59</td>
#       <td>$0.94</td>
#       <td>$8.80</td>
#     </tr>
#     <tr>
#       <th>Largest winning trade</th>
#       <td>$874001.42</td>
#       <td>$94219.96</td>
#       <td>$874001.42</td>
#     </tr>
#     <tr>
#       <th>Largest losing trade</th>
#       <td>$-591196.15</td>
#       <td>$-591196.15</td>
#       <td>$-8581.91</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Duration stats</th>
#       <th>All trades</th>
#       <th>Short trades</th>
#       <th>Long trades</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Avg duration</th>
#       <td>207 days 17:05:02.086872</td>
#       <td>180 days 16:12:54.501992</td>
#       <td>233 days 03:04:08.992509</td>
#     </tr>
#     <tr>
#       <th>Median duration</th>
#       <td>222 days 23:00:00</td>
#       <td>191 days 23:00:00</td>
#       <td>265 days 00:00:00</td>
#     </tr>
#     <tr>
#       <th>Longest duration</th>
#       <td>348 days 00:00:00</td>
#       <td>273 days 00:00:00</td>
#       <td>348 days 00:00:00</td>
#     </tr>
#     <tr>
#       <th>Shortest duration</th>
#       <td>0 days 14:31:59</td>
#       <td>0 days 14:31:59</td>
#       <td>6 days 00:00:00</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Return stats</th>
#       <th>All trades</th>
#       <th>Short trades</th>
#       <th>Long trades</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Avg returns all round_trips</th>
#       <td>0.07%</td>
#       <td>0.03%</td>
#       <td>0.12%</td>
#     </tr>
#     <tr>
#       <th>Avg returns winning</th>
#       <td>0.14%</td>
#       <td>0.13%</td>
#       <td>0.15%</td>
#     </tr>
#     <tr>
#       <th>Avg returns losing</th>
#       <td>-0.08%</td>
#       <td>-0.11%</td>
#       <td>-0.02%</td>
#     </tr>
#     <tr>
#       <th>Median returns all round_trips</th>
#       <td>0.04%</td>
#       <td>0.01%</td>
#       <td>0.05%</td>
#     </tr>
#     <tr>
#       <th>Median returns winning</th>
#       <td>0.07%</td>
#       <td>0.07%</td>
#       <td>0.07%</td>
#     </tr>
#     <tr>
#       <th>Median returns losing</th>
#       <td>-0.03%</td>
#       <td>-0.05%</td>
#       <td>-0.01%</td>
#     </tr>
#     <tr>
#       <th>Largest winning trade</th>
#       <td>5.79%</td>
#       <td>5.79%</td>
#       <td>2.07%</td>
#     </tr>
#     <tr>
#       <th>Largest losing trade</th>
#       <td>-3.91%</td>
#       <td>-3.91%</td>
#       <td>-0.11%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Symbol stats</th>
#       <th>AMZN-16841</th>
#       <th>IBM-3766</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Avg returns all round_trips</th>
#       <td>0.12%</td>
#       <td>0.03%</td>
#     </tr>
#     <tr>
#       <th>Avg returns winning</th>
#       <td>0.14%</td>
#       <td>0.13%</td>
#     </tr>
#     <tr>
#       <th>Avg returns losing</th>
#       <td>-0.02%</td>
#       <td>-0.11%</td>
#     </tr>
#     <tr>
#       <th>Median returns all round_trips</th>
#       <td>0.05%</td>
#       <td>0.01%</td>
#     </tr>
#     <tr>
#       <th>Median returns winning</th>
#       <td>0.07%</td>
#       <td>0.07%</td>
#     </tr>
#     <tr>
#       <th>Median returns losing</th>
#       <td>-0.01%</td>
#       <td>-0.05%</td>
#     </tr>
#     <tr>
#       <th>Largest winning trade</th>
#       <td>2.07%</td>
#       <td>5.79%</td>
#     </tr>
#     <tr>
#       <th>Largest losing trade</th>
#       <td>-0.11%</td>
#       <td>-3.91%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Profitability (PnL / PnL total) per name</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>AMZN-16841</th>
#       <td>111.15%</td>
#     </tr>
#     <tr>
#       <th>IBM-3766</th>
#       <td>-11.15%</td>
#     </tr>
#   </tbody>
# </table>
